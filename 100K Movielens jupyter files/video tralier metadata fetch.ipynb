# %%
import numpy as np 
import pandas as pd

# %%
import os
from moviepy.editor import VideoFileClip

# %%
yt_only_tralier = pd.read_csv('CSV files/yt_only_tralier.csv')

# %%
yt_only_tralier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6447 entries, 0 to 6446
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   youtubeId         6447 non-null   object
#  1   movieId           6447 non-null   int64
#  2   title             6447 non-null   object
#  3   trailer_present   6447 non-null   int64
#  4   video downloaded  6447 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 252.0+ KB

# %%
import os
from moviepy.editor import VideoFileClip
import pandas as pd
import numpy as np

# Create empty lists to hold the metadata
durations = []
fps = []
widths = []
heights = []
aspect_ratios = []

# Iterate over the 'movieId' column of the dataframe
for movie_id in yt_only_tralier['movieId']:
    # Construct the file name using the movie_id
    file_name = f"{movie_id}.mp4"
    
    # Construct the path to the video file inside the 'yt trailers' folder
    file_path = os.path.join("yt trailers", file_name)
    
    # Initialize variables for metadata
    duration = None
    video_fps = None
    width = None
    height = None
    aspect_ratio = None

    try:
        # Load the video file to get its metadata
        with VideoFileClip(file_path) as video:
            duration = int(video.duration)
            video_fps = int(video.fps)
            width = int(video.size[0])
            height = int(video.size[1])
            aspect_ratio = round(width / height, 2)
    except (OSError, IndexError):
        print(f"Failed to extract metadata for video file {file_name}.")
    
    # Append the metadata to the lists
    durations.append(duration)
    fps.append(video_fps)
    widths.append(width)
    heights.append(height)
    aspect_ratios.append(aspect_ratio)

# Add the metadata to the dataframe as new columns
yt_only_tralier['Durations'] = durations
yt_only_tralier['FPS'] = fps
yt_only_tralier['Width'] = widths
yt_only_tralier['Height'] = heights
yt_only_tralier['Aspect Ratio'] = aspect_ratios

# Replace None values with NaN for consistency
yt_only_tralier.fillna(value=np.nan, inplace=True)

# %%
yt_only_tralier
# Out:
#         youtubeId  movieId                                       title  \
# 0     K26_sDKnvMU        1                            Toy Story (1995)
# 1     3LPANjHlPxo        2                              Jumanji (1995)
# 2     rEnOoWs3FuA        3                     Grumpier Old Men (1995)
# 3     j9xml1CxgXI        4                    Waiting to Exhale (1995)
# 4     2GfZl4kuVNI        6                                 Heat (1995)
# ...           ...      ...                                         ...
# 6442  _Buvv8StMGw   130682                                 Muck (2015)
# 6443  qCD9BG7ioOc   130970  George Carlin: Life Is Worth Losing (2005)
# 6444  zElDJ1f3Jk0   130980         The Day That Lasted 21 Years (2012)
# 6445  lEqrpuU9fYI   131013                             Get Hard (2015)
# 6446  zildFIFKjlc   131168                              Phoenix (2014)
#
#       trailer_present  video downloaded  Durations  FPS  Width  Height  \
# ...

# %%
yt_only_tralier.describe()
# Out:
#              movieId  trailer_present  video downloaded    Durations  \
# count    6447.000000           6447.0            6447.0  6447.000000
# mean    26283.050411              1.0               0.0   172.347448
# std     35472.899945              0.0               0.0   475.598739
# min         1.000000              1.0               0.0    12.000000
# 25%      2607.500000              1.0               0.0   100.000000
# 50%      5693.000000              1.0               0.0   129.000000
# 75%     47608.000000              1.0               0.0   150.000000
# max    131168.000000              1.0               0.0  9075.000000
#
#                FPS        Width       Height  Aspect Ratio
# count  6447.000000  6447.000000  6447.000000   6447.000000
# mean     24.896386   927.777881   546.619203      1.651044
# std       3.580872   552.630648   280.060035      0.296815
# min       6.000000   158.000000   112.000000      1.000000
# ...

# %%
yt_only_tralier.to_csv('CSV files/trial.csv', index=False)

# %%
sample_df = yt_only_tralier.sample(10).copy()  # Create a copy to avoid modifying test_df

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 4250 to 5883
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   youtubeId         10 non-null     object
#  1   movieId           10 non-null     int64
#  2   title             10 non-null     object
#  3   trailer_present   10 non-null     int64
#  4   video downloaded  10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 480.0+ bytes
