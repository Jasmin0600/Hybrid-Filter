# %%
import pandas as pd

# %%
ratings_small_filtered = pd.read_csv(r'C:\Users\jasmi\Desktop\Research\Projects\CIKM Confernce paper\CSV files\ratings_small_filtered.csv')
All_parts_objects = pd.read_csv(r'C:\Users\jasmi\Desktop\Research\Projects\CIKM Confernce paper\CSV files\Object mappings\All_parts_objects.csv', index_col=0)

# %%
All_parts_objects
# Out:
#         youtubeId  movieId                                       title  \
# 0     K26_sDKnvMU        1                            Toy Story (1995)
# 1     3LPANjHlPxo        2                              Jumanji (1995)
# 2     rEnOoWs3FuA        3                     Grumpier Old Men (1995)
# 3     j9xml1CxgXI        4                    Waiting to Exhale (1995)
# 4     2GfZl4kuVNI        6                                 Heat (1995)
# ...           ...      ...                                         ...
# 6342  _Buvv8StMGw   130682                                 Muck (2015)
# 6343  qCD9BG7ioOc   130970  George Carlin: Life Is Worth Losing (2005)
# 6344  zElDJ1f3Jk0   130980         The Day That Lasted 21 Years (2012)
# 6345  lEqrpuU9fYI   131013                             Get Hard (2015)
# 6346  zildFIFKjlc   131168                              Phoenix (2014)
#
#       trailer_present  video downloaded  Durations  FPS  Width  Height  \
# ...

# %%
unique_movie_ids = list(All_parts_objects['movieId'].unique())

# %%
len(unique_movie_ids)
# Out:
# 6347

# %%
ratings_small_filtered
# Out:
#        userId  movieId  rating   timestamp
# 0           1       31     2.5  1260759144
# 1           1     1061     3.0  1260759182
# 2           1     1129     2.0  1260759185
# 3           1     1172     4.0  1260759205
# 4           1     1263     2.0  1260759151
# ...       ...      ...     ...         ...
# 82357     671     6212     2.5  1065149436
# 82358     671     6268     2.5  1065579370
# 82359     671     6365     4.0  1070940363
# 82360     671     6385     2.5  1070979663
# 82361     671     6565     3.5  1074784724
#
# [82362 rows x 4 columns]

# %%
ratings_small_filtered_2 = ratings_small_filtered[ratings_small_filtered["movieId"].isin(unique_movie_ids)]

# %%
ratings_small_filtered_2
# Out:
#        userId  movieId  rating   timestamp
# 0           1       31     2.5  1260759144
# 1           1     1061     3.0  1260759182
# 2           1     1129     2.0  1260759185
# 3           1     1172     4.0  1260759205
# 4           1     1263     2.0  1260759151
# ...       ...      ...     ...         ...
# 82357     671     6212     2.5  1065149436
# 82358     671     6268     2.5  1065579370
# 82359     671     6365     4.0  1070940363
# 82360     671     6385     2.5  1070979663
# 82361     671     6565     3.5  1074784724
#
# [81730 rows x 4 columns]

# %%
ratings_small_filtered_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81730 entries, 0 to 82361
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     81730 non-null  int64
#  1   movieId    81730 non-null  int64
#  2   rating     81730 non-null  float64
#  3   timestamp  81730 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
ratings_small_filtered_2 = ratings_small_filtered_2.reset_index(drop=True)

# %%
ratings_small_filtered_2
# Out:
#        userId  movieId  rating   timestamp
# 0           1       31     2.5  1260759144
# 1           1     1061     3.0  1260759182
# 2           1     1129     2.0  1260759185
# 3           1     1172     4.0  1260759205
# 4           1     1263     2.0  1260759151
# ...       ...      ...     ...         ...
# 81725     671     6212     2.5  1065149436
# 81726     671     6268     2.5  1065579370
# 81727     671     6365     4.0  1070940363
# 81728     671     6385     2.5  1070979663
# 81729     671     6565     3.5  1074784724
#
# [81730 rows x 4 columns]

# %%
ratings_small_filtered_2.to_csv('ratings_small_filtered_2.csv')
